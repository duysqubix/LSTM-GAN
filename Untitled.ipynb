# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from model import GAN, Discriminator, Generator, DataGenerator

# %%
gan = GAN(latent_dim=5, seq_length=30, batch_size=128)
gan.discriminator.model.summary()
tf.keras.utils.plot_model(gan.model, show_shapes=True)
gan.generator.model.load_weights("generator_weights.h5")
gan.discriminator.model.load_weights("discriminator_weights.h5")
# Out:
# Model: "discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# d_lstm (LSTM)                (None, 30, 100)           40800
# _________________________________________________________________
# d_lstm2 (LSTM)               (None, 30, 100)           80400
# _________________________________________________________________
# d_output (Dense)             (None, 30, 1)             101
# =================================================================
# Total params: 242,602
# Trainable params: 121,301
# Non-trainable params: 121,301
# _________________________________________________________________
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.

# %%
import time
for i in range(3):
    start = time.time()
    print("Training Round: ", i+1)
    gan.train(epochs=5, n_eval=1, d_train_steps=3)
    gan.generator.model.save_weights("generator_weights.h5"); print("Saved Weights Generator")
    gan.discriminator.model.save_weights("discriminator_weights.h5"); print("Saved Weights Discriminator")
    print("Finished Round: {} in {}s".format(i+1, time.time()-start))
# Out:
# Training Round:  1
# Begin Training with 109 steps per epoch for every 3 trains on discriminator
# Epoch: 0/5 Real Loss: 0.08349428077538808	Fake Loss: 0.07058945794900258
# Epoch: 1/5 Real Loss: 0.09297243754069011	Fake Loss: 0.07675772408644359
# Epoch: 2/5 Real Loss: 0.08473045627276103	Fake Loss: 0.07072987655798595
# Epoch: 3/5 Real Loss: 0.07970674832661946	Fake Loss: 0.06413363789518674
# Epoch: 4/5 Real Loss: 0.07414824763933818	Fake Loss: 0.05633997917175293
# Epoch: 5/5 Real Loss: 0.2347080409526825	Fake Loss: 0.16751620173454285
# Saved Weights Generator
# Saved Weights Discriminator
# Finished Round: 1 in 222.2714719772339s
# Training Round:  2
# Begin Training with 109 steps per epoch for every 3 trains on discriminator
# Epoch: 0/5 Real Loss: 0.0924299235145251	Fake Loss: 0.06011718139052391
# Epoch: 1/5 Real Loss: 0.08200992892185847	Fake Loss: 0.0645347386598587
# Epoch: 2/5 Real Loss: 0.07190501689910889	Fake Loss: 0.05757732565204302
# Epoch: 3/5 Real Loss: 0.06676708534359932	Fake Loss: 0.057150290658076607
# Epoch: 4/5 Real Loss: 0.0819703886906306	Fake Loss: 0.06486869603395462
# Epoch: 5/5 Real Loss: 0.07212000588576	Fake Loss: 0.06079352895418803
# Saved Weights Generator
# Saved Weights Discriminator
# Finished Round: 2 in 214.57047605514526s
# Training Round:  3
# Begin Training with 109 steps per epoch for every 3 trains on discriminator
# Epoch: 0/5 Real Loss: 0.09660535057385762	Fake Loss: 0.07205988218386968
# Epoch: 1/5 Real Loss: 0.07487877209981282	Fake Loss: 0.060854786386092506
# Epoch: 2/5 Real Loss: 0.07370560119549434	Fake Loss: 0.05579508220156034
# Epoch: 3/5 Real Loss: 0.08194191257158916	Fake Loss: 0.09139414876699448
# Epoch: 4/5 Real Loss: 0.06781284386912982	Fake Loss: 0.056320576618115105
# Epoch: 5/5 Real Loss: 0.07301792502403259	Fake Loss: 0.06059629221757253
# Saved Weights Generator
# Saved Weights Discriminator
# Finished Round: 3 in 218.1147599220276s

# %%
gan.real_loss = np.array(gan.real_loss)
# dy_dx = gan.real_loss[1:]-gan.real_loss[:-1]
plt.plot(gan.real_loss, label='Real Accuracy')
plt.plot(gan.fake_loss, label='Fake Accuracy')
# plt.plot(dy_dx, label='dydx')
plt.legend()
gan.discriminator.model.metrics_names
# Out:
# ['loss', 'acc']

# %%
pred= gan.generator.fake_samples()[0]
single_pred = pred[np.random.randint(0, len(pred)), :, 0]
conv = np.convolve(single_pred, [1/3, 1/3, 1/3], 'same')
true = gan.generator.real_samples()[0][np.random.randint(0, len(pred)), : , 0]
conv_true = np.convolve(true, [1/3, 1/3, 1/3], 'same')
plt.figure(figsize=(10,5))
plt.plot(conv, label='Conv')
# plt.plot(conv_true, label='real')

plt.legend()
plt.show()

# %%
pred = gan.generator.fake_samples()[0].flatten()
pred = np.convolve(pred, [1/3, 1/3, 1/3], 'same')
plt.figure(figsize=(200,10))
plt.plot(pred[:])

# %%
def train_model(gname, dname, epochs=5):
    gan = GAN(latent_dim=5, seq_length=200, batch_size=28)
    gan.discriminator.model.summary()
#     tf.keras.utils.plot_model(gan.model, show_shapes=True)

    import time
    for i in range(3):
        start = time.time()
        print("Training Round: ", i+1)
        gan.train(epochs=epochs, n_eval=1, d_train_steps=3)
        gan.generator.model.save_weights("{}.h5"); print("Saved Weights Generator")
        gan.discriminator.model.save_weights("{}_weights.h5"); print("Saved Weights Discriminator")
        print("Finished Round: {} in {}s".format(i+1, time.time()-start))

# %%
train_model("generator_2", "discriminator_2", epochs=5)
# Out:
# Model: "discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# d_lstm (LSTM)                (None, 200, 100)          40800
# _________________________________________________________________
# d_lstm2 (LSTM)               (None, 200, 100)          80400
# _________________________________________________________________
# d_output (Dense)             (None, 200, 1)            101
# =================================================================
# Total params: 242,602
# Trainable params: 121,301
# Non-trainable params: 121,301
# _________________________________________________________________
# Training Round:  1
# Begin Training with 500 steps per epoch for every 3 trains on discriminator
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-1650e8af513a> in <module>
# ----> 1 train_model("generator_2", "discriminator_2", epochs=5)
#
# <ipython-input-101-8ea832edd226> in train_model(gname, dname, epochs)
#       8         start = time.time()
#       9         print("Training Round: ", i+1)
# ---> 10         gan.train(epochs=epochs, n_eval=1, d_train_steps=3)
#      11         gan.generator.model.save_weights("{}.h5"); print("Saved Weights Generator")
#      12         gan.discriminator.model.save_weights("{}_weights.h5"); print("Saved Weights Discriminator")
#
# F:\RGAN\LSTM-GAN\model.py in train(self, epochs, n_eval, d_train_steps)
#     145                     x_f, y_f = self.generator.fake_samples()
#     146
# --> 147                     real = self.discriminator.model.fit(x_r, y_r, epochs=1, batch_size=self.batch_size, verbose=0, shuffle=True).history
#     148                     fake = self.discriminator.model.fit(x_f, y_f, epochs=1, batch_size=self.batch_size, verbose=0, shuffle=True).history
#     149
#
# c:\users\duan_\anaconda2\envs\tf2\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     732         max_queue_size=max_queue_size,
#     733         workers=workers,
# --> 734         use_multiprocessing=use_multiprocessing)
#     735
#     736   def evaluate(self,
#
# c:\users\duan_\anaconda2\envs\tf2\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     222           validation_data=validation_data,
#     223           validation_steps=validation_steps,
# --> 224           distribution_strategy=strategy)
#     225
#     226       total_samples = _get_total_number_of_samples(training_data_adapter)
#
# c:\users\duan_\anaconda2\envs\tf2\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in _process_training_inputs(model, x, y, batch_size, epochs, sample_weights, class_weights, steps_per_epoch, validation_split, validation_data, validation_steps, shuffle, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     545         max_queue_size=max_queue_size,
#     546         workers=workers,
# --> 547         use_multiprocessing=use_multiprocessing)
#     548     val_adapter = None
#     549     if validation_data:
#
# c:\users\duan_\anaconda2\envs\tf2\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in _process_inputs(model, x, y, batch_size, epochs, sample_weights, class_weights, shuffle, steps, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     591         batch_size=batch_size,
#     592         check_steps=False,
# --> 593         steps=steps)
#     594   adapter = adapter_cls(
#     595       x,
#
# c:\users\duan_\anaconda2\envs\tf2\lib\site-packages\tensorflow_core\python\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
#    2435           feed_input_shapes,
#    2436           check_batch_axis=False,  # Don't enforce the batch size.
# -> 2437           exception_prefix='input')
#    2438
#    2439     # Get typespecs for the input data and sanitize it if necessary.
#
# c:\users\duan_\anaconda2\envs\tf2\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     571                              ': expected ' + names[i] + ' to have shape ' +
#     572                              str(shape) + ' but got array with shape ' +
# --> 573                              str(data_shape))
#     574   return data
#     575
#
# ValueError: Error when checking input: expected d_lstm_input to have shape (200, 1) but got array with shape (30, 1)
